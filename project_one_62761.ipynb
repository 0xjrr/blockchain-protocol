# %%
import hashlib
import time
import random
from operator import*

# %% [markdown]
# # Understanding Blockchain: Proof of Work and Merkle Tree

# %% [markdown]
# ## Introduction
# In this document, we'll explore the fundamental concepts of blockchain technology, focusing on the Proof of Work (PoW) consensus mechanism and the Merkle Tree data structure that underpins the blockchain's transactional integrity. We'll implement these concepts in Python and examine their role in maintaining the security and integrity of a blockchain.

# %% [markdown]
# ## Proof of Work (PoW)
# ### Overview
# Proof of Work (PoW) is a consensus mechanism used in blockchain networks to achieve agreement on the state of the network. It involves solving a computationally intensive puzzle to validate transactions and create new blocks in the blockchain. PoW is used in popular blockchain networks like Bitcoin and Ethereum.
#
# ### Explanation
# Imagine you're a miner, and you want to add a block to the blockchain. The block includes a bunch of transactions, and your job is to find a special number called a "nonce" that, when combined with other block data, produces a specific pattern when hashed.
#
# ### Finding the Nonce
# - You start with the block's data, including the transactions and a previous block's hash.
# - You also pick a random number called a nonce and combine it with the block's data.
# - Next, you use a computer to hash this combined data. A hash is like a fingerprint for data – it's unique to each set of data.
# - If the resulting hash doesn't match the required pattern (usually starting with a certain number of zeros), you try another nonce and repeat the process.
# - You keep trying different nonces until you find one that produces a hash with the required pattern.
# ### Why It's Important
# The PoW puzzle is intentionally difficult and time-consuming to solve, but verifying the solution is easy. This ensures that adding a block to the blockchain requires real computational work, making it expensive for someone to tamper with the blockchain's history, but easy for others to verify the work.

# %% [markdown]
# ### Implementation
# We'll begin by implementing the PoW algorithm, including the Block and Blockchain classes.

# %%
class Block:
    def __init__(self, block_id, previous_hash, transactions, timestamp):
        self.block_id = block_id
        self.previous_hash = previous_hash
        self.transactions = transactions
        self.timestamp = timestamp
        self.nonce = 0

    def compute_hash(self):
        return hashlib.sha256((str(self.block_id) + self.previous_hash + str(self.transactions) + str(self.timestamp) + str(self.nonce)).encode()).hexdigest()

    def __str__(self):
        return f"\nBlock ID: {self.block_id}\nPrevious Hash: {self.previous_hash}\nTransactions: {self.transactions}\nTimestamp: {self.timestamp}\nNonce: {self.nonce}"


class Blockchain:
    def __init__(self):
        self.chain = []
        self.difficulty = 4  # Initial difficulty level
        self.target_time_interval = 15  # Target time interval between blocks in seconds
        self.block_count_since_adjustment = 0
        self.total_time_since_adjustment = 0
        # Create genesis block (initial block)
        genesis_block = Block(0, "0", "Genesis", time.time())
        self.add_block(genesis_block)

    def add_block(self, new_block):
        if len(self.chain) > 0:
            new_block.previous_hash = self.chain[-1].compute_hash()

        # Mine the block with adjusted difficulty
        new_block, time_taken = self.mine_block(new_block)

        self.chain.append(new_block)
        print("Block mined successfully.")
        print("Time taken:", time_taken, "seconds")

        self.block_count_since_adjustment += 1
        self.total_time_since_adjustment += time_taken

        # Adjust difficulty every multiple of 10 blocks
        if self.block_count_since_adjustment % 10 == 0:
            self.adjust_difficulty()

    def mine_block(self, block):
        start_time = time.time()
        target = "0" * self.difficulty

        while block.compute_hash()[:self.difficulty] != target:
            block.nonce += 1

        end_time = time.time()
        time_taken = end_time - start_time

        return block, time_taken

    def adjust_difficulty(self):
        average_time = self.total_time_since_adjustment / self.block_count_since_adjustment

        print("Average time taken to mine a block:", average_time, "seconds")

        buffer = 5  # Buffer time interval

        if average_time < self.target_time_interval - 10: # Decrease difficulty by 1 if average time is less than target time interval - 10 seconds
            self.difficulty += 1
        elif average_time > self.target_time_interval + 10 and self.difficulty > 1: # Increase difficulty by 1 if average time is more than target time interval + 10 seconds
            self.difficulty -= 1

        print("Difficulty adjusted to:", self.difficulty)

        # Reset counters
        self.block_count_since_adjustment = 0
        self.total_time_since_adjustment = 0

# %% [markdown]
# ### Usage Example
# We'll demonstrate the usage of the PoW algorithm by creating a blockchain and adding blocks to it.

# %%
blockchain = Blockchain()

# Create and add more blocks
for i in range(1, 100):
    print("\n---------Adding block #", i, "---------")
    new_block = Block(i, "", "Transaction data " + str(i), time.time())
    blockchain.add_block(new_block)
    print("Block #", i, " added to the blockchain", blockchain.chain[-1])
# Out:
# Block mined successfully.
# Time taken: 0.007294178009033203 seconds
#
# ---------Adding block # 1 ---------
# Block mined successfully.
# Time taken: 0.06079244613647461 seconds
# Block # 1  added to the blockchain
# Block ID: 1
# Previous Hash: 000060c16669f3d94586b89a597b2694d57b3d597bd58fd33b843ddc11329979
# Transactions: Transaction data 1
# Timestamp: 1714913833.8712568
# Nonce: 38637
#
# ---------Adding block # 2 ---------
# Block mined successfully.
# Time taken: 0.08472061157226562 seconds
# Block # 2  added to the blockchain
# Block ID: 2
# Previous Hash: 0000f1a3b2825fe86850e060d41b14e7460d42fad6294959edde8d7c98f9adfc
# Transactions: Transaction data 2
# Timestamp: 1714913833.9322736
# Nonce: 58417
#
# ---------Adding block # 3 ---------
# Block mined successfully.
# Time taken: 0.10257673263549805 seconds
# Block # 3  added to the blockchain
# Block ID: 3
# Previous Hash: 0000d401820d205ea28c917f51e247cd124cf4c40a0a63d79459fea356f5ec2d
# Transactions: Transaction data 3
# Timestamp: 1714913834.0171177
# Nonce: 73995
#
# ---------Adding block # 4 ---------
# Block mined successfully.
# Time taken: 0.015478372573852539 seconds
# Block # 4  added to the blockchain
# Block ID: 4
# Previous Hash: 00006a4bd97c43073c7167046a4692a51d849ccdd397c1d1e6f9798a3eacb5d7
# Transactions: Transaction data 4
# Timestamp: 1714913834.1201797
# Nonce: 10360
#
# ---------Adding block # 5 ---------
# Block mined successfully.
# Time taken: 0.021692991256713867 seconds
# Block # 5  added to the blockchain
# Block ID: 5
# Previous Hash: 0000348555735055e14816d3f037d7d2cdad194126d36f31448a3ee5058f1f23
# Transactions: Transaction data 5
# Timestamp: 1714913834.1357658
# Nonce: 12689
#
# ---------Adding block # 6 ---------
# Block mined successfully.
# Time taken: 0.11961126327514648 seconds
# Block # 6  added to the blockchain
# Block ID: 6
# Previous Hash: 0000860f41d54e41d500d41f7ddb82639e33589916b2eddeee271a2e4c7e657c
# Transactions: Transaction data 6
# Timestamp: 1714913834.1575613
# Nonce: 81078
#
# ---------Adding block # 7 ---------
# Block mined successfully.
# Time taken: 0.015649080276489258 seconds
# Block # 7  added to the blockchain
# Block ID: 7
# Previous Hash: 00007b73ba07c00187e3f879fdf7412bb3503a0c30e76a7fc41ba7b9c49f4764
# Transactions: Transaction data 7
# Timestamp: 1714913834.2772663
# Nonce: 11673
#
# ---------Adding block # 8 ---------
# Block mined successfully.
# Time taken: 0.007486581802368164 seconds
# Block # 8  added to the blockchain
# Block ID: 8
# Previous Hash: 0000b32a0168246f2be95c1ce982057cb56be7d3c82d6f6f3c6d8f4ee023d65a
# Transactions: Transaction data 8
# Timestamp: 1714913834.2929995
# Nonce: 5781
#
# ---------Adding block # 9 ---------
# Block mined successfully.
# Time taken: 0.031935691833496094 seconds
# Average time taken to mine a block: 0.046723794937133786 seconds
# Difficulty adjusted to: 5
# Block # 9  added to the blockchain
# Block ID: 9
# Previous Hash: 00004d4056e2bfabd581e3745c582e5939af516c87a7233cb80e634efa9715c0
# Transactions: Transaction data 9
# Timestamp: 1714913834.3005376
# Nonce: 23863
#
# ---------Adding block # 10 ---------
# Block mined successfully.
# Time taken: 0.24957489967346191 seconds
# Block # 10  added to the blockchain
# Block ID: 10
# Previous Hash: 0000c501821baa14a387f97da60b121bfc67e7a512589182c8bea17fa8967ec2
# Transactions: Transaction data 10
# Timestamp: 1714913834.3336623
# Nonce: 175804
#
# ---------Adding block # 11 ---------
# Block mined successfully.
# Time taken: 1.1298325061798096 seconds
# Block # 11  added to the blockchain
# Block ID: 11
# Previous Hash: 000008d9daa4faa25228fdf5d9652d2dd454a3dd3af0c4655232df99e29a31c1
# Transactions: Transaction data 11
# Timestamp: 1714913834.583525
# Nonce: 821849
#
# ---------Adding block # 12 ---------
# Block mined successfully.
# Time taken: 2.684818983078003 seconds
# Block # 12  added to the blockchain
# Block ID: 12
# Previous Hash: 00000cf8bb015a8ac9f4a2f32b736a27c521285526ee2a2fb9cbe41c82f44ca8
# Transactions: Transaction data 12
# Timestamp: 1714913835.7136621
# Nonce: 1816812
#
# ---------Adding block # 13 ---------
# Block mined successfully.
# Time taken: 1.1213345527648926 seconds
# Block # 13  added to the blockchain
# Block ID: 13
# Previous Hash: 0000004a3585adf0c3337321fba5151851e4c3bd13c0a8e610649c9bbd415330
# Transactions: Transaction data 13
# Timestamp: 1714913838.3987658
# Nonce: 787547
#
# ---------Adding block # 14 ---------
# Block mined successfully.
# Time taken: 3.302011251449585 seconds
# Block # 14  added to the blockchain
# Block ID: 14
# Previous Hash: 0000041574a99248e1356e8563f787323163ed6e0e972615208d7d0a96dbcc39
# Transactions: Transaction data 14
# Timestamp: 1714913839.520395
# Nonce: 2332346
#
# ---------Adding block # 15 ---------
# Block mined successfully.
# Time taken: 0.8447425365447998 seconds
# Block # 15  added to the blockchain
# Block ID: 15
# Previous Hash: 00000a1cfb1a69dafb41481ee347d868271d3c49a2eab00e673559f7fb5bf467
# Transactions: Transaction data 15
# Timestamp: 1714913842.8226333
# Nonce: 611481
#
# ---------Adding block # 16 ---------
# Block mined successfully.
# Time taken: 1.0782475471496582 seconds
# Block # 16  added to the blockchain
# Block ID: 16
# Previous Hash: 00000f9e780aea484a8f37006c21a4e6436368b62c1e4447e3a908a9b4057d99
# Transactions: Transaction data 16
# Timestamp: 1714913843.6677396
# Nonce: 751342
#
# ---------Adding block # 17 ---------
# Block mined successfully.
# Time taken: 1.0171091556549072 seconds
# Block # 17  added to the blockchain
# Block ID: 17
# Previous Hash: 00000ef22d8de51b40d68c21478642bf4dbd356697947e66c94661868ed63215
# Transactions: Transaction data 17
# Timestamp: 1714913844.7462313
# Nonce: 705643
#
# ---------Adding block # 18 ---------
# Block mined successfully.
# Time taken: 0.371260404586792 seconds
# Block # 18  added to the blockchain
# Block ID: 18
# Previous Hash: 00000716229f53302d3ba6fe6947e923c291272502468bf0950accb60cf63965
# Transactions: Transaction data 18
# Timestamp: 1714913845.763578
# Nonce: 263167
#
# ---------Adding block # 19 ---------
# Block mined successfully.
# Time taken: 0.3224349021911621 seconds
# Average time taken to mine a block: 1.2121366739273072 seconds
# Difficulty adjusted to: 6
# Block # 19  added to the blockchain
# Block ID: 19
# Previous Hash: 00000274ad9e7a8ccc8101eb983f16cb684b8a759c9c0324d57d389affc0f640
# Transactions: Transaction data 19
# Timestamp: 1714913846.1350431
# Nonce: 219619
#
# ---------Adding block # 20 ---------
# Block mined successfully.
# Time taken: 54.145490884780884 seconds
# Block # 20  added to the blockchain
# Block ID: 20
# Previous Hash: 0000080e0086a4928e5fbd5f7f8ccd77a2a4f0164c7abd1676f656cf9ba851b4
# Transactions: Transaction data 20
# Timestamp: 1714913846.457676
# Nonce: 38809154
#
# ---------Adding block # 21 ---------
# Block mined successfully.
# Time taken: 58.09250092506409 seconds
# Block # 21  added to the blockchain
# Block ID: 21
# Previous Hash: 000000effb6fe777cc54be20b172dbcadd0c37a40041157ac41020cfc97a11cb
# Transactions: Transaction data 21
# Timestamp: 1714913900.6034186
# Nonce: 41239150
#
# ---------Adding block # 22 ---------
# Block mined successfully.
# Time taken: 43.38546395301819 seconds
# Block # 22  added to the blockchain
# Block ID: 22
# Previous Hash: 0000008abbdbf251f572f5a5fdf84b42f0ccc224527b21aebf2ca711dee55d2f
# Transactions: Transaction data 22
# Timestamp: 1714913958.69614
# Nonce: 31148328
#
# ---------Adding block # 23 ---------
# Block mined successfully.
# Time taken: 4.362948179244995 seconds
# Block # 23  added to the blockchain
# Block ID: 23
# Previous Hash: 0000008efde171fc94ef832439a6877a30694206203d35ece9f774c4569d6909
# Transactions: Transaction data 23
# Timestamp: 1714914002.0817807
# Nonce: 3006114
#
# ---------Adding block # 24 ---------
# Block mined successfully.
# Time taken: 3.2878191471099854 seconds
# Block # 24  added to the blockchain
# Block ID: 24
# Previous Hash: 000000da66bd5d22371b1a6e4a437fe3e378568b301c78c73168285b3f19c313
# Transactions: Transaction data 24
# Timestamp: 1714914006.44493
# Nonce: 2368388
#
# ---------Adding block # 25 ---------
# Block mined successfully.
# Time taken: 21.964745044708252 seconds
# Block # 25  added to the blockchain
# Block ID: 25
# Previous Hash: 000000e287ef9521364292ad371b1f9c38155a296d20de36d019351a1acf6a77
# Transactions: Transaction data 25
# Timestamp: 1714914009.7329748
# Nonce: 15674470
#
# ---------Adding block # 26 ---------
# Block mined successfully.
# Time taken: 46.52452564239502 seconds
# Block # 26  added to the blockchain
# Block ID: 26
# Previous Hash: 000000cc5964f9fc7ec99c0e2585344abcd2733bb8b78e595180e940a72e7ebb
# Transactions: Transaction data 26
# Timestamp: 1714914031.6979153
# Nonce: 33181045
#
# ---------Adding block # 27 ---------
# Block mined successfully.
# Time taken: 47.378825664520264 seconds
# Block # 27  added to the blockchain
# Block ID: 27
# Previous Hash: 0000003d31c98413abe0c83504ec536d4c3fec97ed602dbb87b997ce37feb826
# Transactions: Transaction data 27
# Timestamp: 1714914078.2227397
# Nonce: 33670881
#
# ---------Adding block # 28 ---------
# Block mined successfully.
# Time taken: 2.233362913131714 seconds
# Block # 28  added to the blockchain
# Block ID: 28
# Previous Hash: 00000033ef8517db6a8e0a1e90c209069929fe9c0d635bcc487bbcb1747883c6
# Transactions: Transaction data 28
# Timestamp: 1714914125.6018531
# Nonce: 1604096
#
# ---------Adding block # 29 ---------
# Block mined successfully.
# Time taken: 39.91295862197876 seconds
# Average time taken to mine a block: 32.12886409759521 seconds
# Difficulty adjusted to: 5
# Block # 29  added to the blockchain
# Block ID: 29
# Previous Hash: 000000be52a49d1b527a9e6a71ccdae019e63ce89f082e3844ec0a404620dc1a
# Transactions: Transaction data 29
# Timestamp: 1714914127.8353894
# Nonce: 28470118
#
# ---------Adding block # 30 ---------
# Block mined successfully.
# Time taken: 0.861752986907959 seconds
# Block # 30  added to the blockchain
# Block ID: 30
# Previous Hash: 00000042d175edbf2de7317ba23e4e595dd667e984555cc661c64bb626cd563b
# Transactions: Transaction data 30
# Timestamp: 1714914167.7486746
# Nonce: 593980
#
# ---------Adding block # 31 ---------
# Block mined successfully.
# Time taken: 1.9878864288330078 seconds
# Block # 31  added to the blockchain
# Block ID: 31
# Previous Hash: 00000b28b278156efce95e4b806b3b49e7553c396661fc62e796c8f7ba5fef9b
# Transactions: Transaction data 31
# Timestamp: 1714914168.6106088
# Nonce: 1415603
#
# ---------Adding block # 32 ---------
# Block mined successfully.
# Time taken: 0.46364760398864746 seconds
# Block # 32  added to the blockchain
# Block ID: 32
# Previous Hash: 0000035b353650618894cd014c0dc906428fd60ecefa80c4438a6ecc62f1c64e
# Transactions: Transaction data 32
# Timestamp: 1714914170.5987685
# Nonce: 332126
#
# ---------Adding block # 33 ---------
# Block mined successfully.
# Time taken: 0.2861921787261963 seconds
# Block # 33  added to the blockchain
# Block ID: 33
# Previous Hash: 0000087803f27caa024affd4fe34fbdbb7edc9e964831cae7318ff025ae76dbd
# Transactions: Transaction data 33
# Timestamp: 1714914171.0625887
# Nonce: 201791
#
# ---------Adding block # 34 ---------
# Block mined successfully.
# Time taken: 1.9759173393249512 seconds
# Block # 34  added to the blockchain
# Block ID: 34
# Previous Hash: 0000079b8b758525f96007c8bd9f48a45b9add6b46d58dc1683a8c798f98b624
# Transactions: Transaction data 34
# Timestamp: 1714914171.3489852
# Nonce: 1397057
#
# ---------Adding block # 35 ---------
# Block mined successfully.
# Time taken: 1.2064988613128662 seconds
# Block # 35  added to the blockchain
# Block ID: 35
# Previous Hash: 00000c07ba86aa22562379572a45474658621d9b28c4b65986fd805a144a7b12
# Transactions: Transaction data 35
# Timestamp: 1714914173.3250864
# Nonce: 874873
#
# ---------Adding block # 36 ---------
# Block mined successfully.
# Time taken: 1.3824689388275146 seconds
# Block # 36  added to the blockchain
# Block ID: 36
# Previous Hash: 000000c0b16085427f6fdbc1cf8474b313c0a80c1985c12218f5434a00ccfd14
# Transactions: Transaction data 36
# Timestamp: 1714914174.5318332
# Nonce: 970747
#
# ---------Adding block # 37 ---------
# Block mined successfully.
# Time taken: 2.312842607498169 seconds
# Block # 37  added to the blockchain
# Block ID: 37
# Previous Hash: 0000091e8c1015b6182888cb7278df2a5b5de4606a3bc6cfc9a9cde9455bc868
# Transactions: Transaction data 37
# Timestamp: 1714914175.9144583
# Nonce: 1654581
#
# ---------Adding block # 38 ---------
# Block mined successfully.
# Time taken: 2.077089309692383 seconds
# Block # 38  added to the blockchain
# Block ID: 38
# Previous Hash: 000006d19c6be42a096d50fb40ced3bf200de9849f8f6afa6e89335702ce7abe
# Transactions: Transaction data 38
# Timestamp: 1714914178.2274766
# Nonce: 1451244
#
# ---------Adding block # 39 ---------
# Block mined successfully.
# Time taken: 1.5447089672088623 seconds
# Average time taken to mine a block: 1.4099005222320558 seconds
# Difficulty adjusted to: 6
# Block # 39  added to the blockchain
# Block ID: 39
# Previous Hash: 00000b2460f7e13d442eb49cc1cda2052647dcd29af4ce4f92aba1c5e9d41e36
# Transactions: Transaction data 39
# Timestamp: 1714914180.3048122
# Nonce: 1102642
#
# ---------Adding block # 40 ---------
# Block mined successfully.
# Time taken: 22.684114694595337 seconds
# Block # 40  added to the blockchain
# Block ID: 40
# Previous Hash: 00000dd098428387907afadc28c5e1125423186f45e2d00045d6c352585a0d89
# Transactions: Transaction data 40
# Timestamp: 1714914181.84971
# Nonce: 16191049
#
# ---------Adding block # 41 ---------
# Block mined successfully.
# Time taken: 28.86933732032776 seconds
# Block # 41  added to the blockchain
# Block ID: 41
# Previous Hash: 000000c375cd855f5685f5dd18261e5c42146e73d9ee5791b7bc92c917a49e63
# Transactions: Transaction data 41
# Timestamp: 1714914204.5341775
# Nonce: 20016125
#
# ---------Adding block # 42 ---------
# Block mined successfully.
# Time taken: 6.088351488113403 seconds
# Block # 42  added to the blockchain
# Block ID: 42
# Previous Hash: 00000083beab1d5611e4a7dbe562f90b2905c3b221bed039f0d8bd5719cf6202
# Transactions: Transaction data 42
# Timestamp: 1714914233.4037135
# Nonce: 4308483
#
# ---------Adding block # 43 ---------
# Block mined successfully.
# Time taken: 70.58217287063599 seconds
# Block # 43  added to the blockchain
# Block ID: 43
# Previous Hash: 0000009aaf4a2bacc9aa2442589e64d060db6f191482a69891d4fae45696bcc8
# Transactions: Transaction data 43
# Timestamp: 1714914239.4922464
# Nonce: 49902937
#
# ---------Adding block # 44 ---------
# Block mined successfully.
# Time taken: 11.393152952194214 seconds
# Block # 44  added to the blockchain
# Block ID: 44
# Previous Hash: 0000002461bcd6c9d6b2f0015b5a982e5e6a51a04c89c3abd93f1e71fffa4fd7
# Transactions: Transaction data 44
# Timestamp: 1714914310.0746076
# Nonce: 7925658
#
# ---------Adding block # 45 ---------
# Block mined successfully.
# Time taken: 1.5034065246582031 seconds
# Block # 45  added to the blockchain
# Block ID: 45
# Previous Hash: 000000c076c4b5b5cd2c3d773439f9eda35eacd8dd4d2e82c8546e2df008c8cf
# Transactions: Transaction data 45
# Timestamp: 1714914321.4680543
# Nonce: 1040532
#
# ---------Adding block # 46 ---------
# Block mined successfully.
# Time taken: 2.0016026496887207 seconds
# Block # 46  added to the blockchain
# Block ID: 46
# Previous Hash: 000000ee811a925b183c944291a1dd1aa6243f3bb26f38bf1339841c26fe6073
# Transactions: Transaction data 46
# Timestamp: 1714914322.9716778
# Nonce: 1422379
#
# ---------Adding block # 47 ---------
# Block mined successfully.
# Time taken: 23.908926248550415 seconds
# Block # 47  added to the blockchain
# Block ID: 47
# Previous Hash: 0000004465971d3feb86cb33e3923c107524f85b2bb57fbf1f3abbd037db508b
# Transactions: Transaction data 47
# Timestamp: 1714914324.9735515
# Nonce: 17045703
#
# ---------Adding block # 48 ---------
# Block mined successfully.
# Time taken: 18.635941982269287 seconds
# Block # 48  added to the blockchain
# Block ID: 48
# Previous Hash: 00000037fca31477570f40bd5ab93c4eadb10876d3b4a8c0337a00b51b20d7ea
# Transactions: Transaction data 48
# Timestamp: 1714914348.882853
# Nonce: 13527734
#
# ---------Adding block # 49 ---------
# Block mined successfully.
# Time taken: 16.725669622421265 seconds
# Average time taken to mine a block: 20.23926763534546 seconds
# Difficulty adjusted to: 6
# Block # 49  added to the blockchain
# Block ID: 49
# Previous Hash: 000000528dd94f0480d1e71d469e1923d57d308a2d7105d437a31131c7f21907
# Transactions: Transaction data 49
# Timestamp: 1714914367.5190535
# Nonce: 11829266
#
# ---------Adding block # 50 ---------
# Block mined successfully.
# Time taken: 2.157536745071411 seconds
# Block # 50  added to the blockchain
# Block ID: 50
# Previous Hash: 0000000f87829f0e2833a93562955838c902e7d51fd78dfa1d6eb1d52ca00b99
# Transactions: Transaction data 50
# Timestamp: 1714914384.244963
# Nonce: 1566601
#
# ---------Adding block # 51 ---------
# Block mined successfully.
# Time taken: 15.968583345413208 seconds
# Block # 51  added to the blockchain
# Block ID: 51
# Previous Hash: 0000006ebf26caec3295c3e7a1daed23be6e8ac7970f588d4ac906f243fc8a55
# Transactions: Transaction data 51
# Timestamp: 1714914386.402693
# Nonce: 11562837
#
# ---------Adding block # 52 ---------
# Block mined successfully.
# Time taken: 1.4517807960510254 seconds
# Block # 52  added to the blockchain
# Block ID: 52
# Previous Hash: 00000000af6aed12f94f2ee72a063ab70fb37d11f72bda5916610bd7cd6d161a
# Transactions: Transaction data 52
# Timestamp: 1714914402.3714397
# Nonce: 1049199
#
# ---------Adding block # 53 ---------
# Block mined successfully.
# Time taken: 10.712931394577026 seconds
# Block # 53  added to the blockchain
# Block ID: 53
# Previous Hash: 0000001e28fa09eedf6e918f95834fcab84381d11605461ce7efae85e5b3f45c
# Transactions: Transaction data 53
# Timestamp: 1714914403.8234708
# Nonce: 7431652
#
# ---------Adding block # 54 ---------
# Block mined successfully.
# Time taken: 2.9695217609405518 seconds
# Block # 54  added to the blockchain
# Block ID: 54
# Previous Hash: 000000d109b5beeedc28a6765cadc0def2500ca2dcdea158c6026479e5fa26d9
# Transactions: Transaction data 54
# Timestamp: 1714914414.5365784
# Nonce: 2081475
#
# ---------Adding block # 55 ---------
# Block mined successfully.
# Time taken: 39.21822428703308 seconds
# Block # 55  added to the blockchain
# Block ID: 55
# Previous Hash: 000000f8628a4ceafe774f84bdea18c43b43fc10ca0fa22ed3173c4be7f856b0
# Transactions: Transaction data 55
# Timestamp: 1714914417.506434
# Nonce: 27680125
#
# ---------Adding block # 56 ---------
# Block mined successfully.
# Time taken: 14.270577669143677 seconds
# Block # 56  added to the blockchain
# Block ID: 56
# Previous Hash: 00000090222f0bbb6c64d471b97c37706344cc05e7477faaa18f3a5bfcd5a99f
# Transactions: Transaction data 56
# Timestamp: 1714914456.724917
# Nonce: 10098779
#
# ---------Adding block # 57 ---------
# Block mined successfully.
# Time taken: 6.522747755050659 seconds
# Block # 57  added to the blockchain
# Block ID: 57
# Previous Hash: 000000c86983f7c60b1a0170947b697b5bb81c74a9d656b4b6dd35a112a9f34d
# Transactions: Transaction data 57
# Timestamp: 1714914470.9957623
# Nonce: 4466220
#
# ---------Adding block # 58 ---------
# Block mined successfully.
# Time taken: 20.733519792556763 seconds
# Block # 58  added to the blockchain
# Block ID: 58
# Previous Hash: 00000042ac5d0b191c570bd4659e850f5f678e7abadbf328f0335163d3fed012
# Transactions: Transaction data 58
# Timestamp: 1714914477.5186899
# Nonce: 14351133
#
# ---------Adding block # 59 ---------
# Block mined successfully.
# Time taken: 1.32952880859375 seconds
# Average time taken to mine a block: 11.533495235443116 seconds
# Difficulty adjusted to: 6
# Block # 59  added to the blockchain
# Block ID: 59
# Previous Hash: 000000638d9fbfebb8ebd63bed9efb011a833ebc6484cff3d66a169de2272b91
# Transactions: Transaction data 59
# Timestamp: 1714914498.2525103
# Nonce: 897477
#
# ---------Adding block # 60 ---------
# Block mined successfully.
# Time taken: 14.574454069137573 seconds
# Block # 60  added to the blockchain
# Block ID: 60
# Previous Hash: 000000da89424eb58b6d907e6da9a154fb0fd57db4828283f4352bc89881e921
# Transactions: Transaction data 60
# Timestamp: 1714914499.5822628
# Nonce: 10176324
#
# ---------Adding block # 61 ---------
# Block mined successfully.
# Time taken: 46.80581045150757 seconds
# Block # 61  added to the blockchain
# Block ID: 61
# Previous Hash: 000000f5ee4fb9261cc5434c007908c609822718e0dc66894129f1cb1301e689
# Transactions: Transaction data 61
# Timestamp: 1714914514.156957
# Nonce: 33637046
#
# ---------Adding block # 62 ---------
# Block mined successfully.
# Time taken: 33.859063386917114 seconds
# Block # 62  added to the blockchain
# Block ID: 62
# Previous Hash: 000000f59be9a78661cf7c8f4332964d44df7f6d11d8e1833084ddb404871a1b
# Transactions: Transaction data 62
# Timestamp: 1714914560.9629395
# Nonce: 23855322
#
# ---------Adding block # 63 ---------
# Block mined successfully.
# Time taken: 19.96518063545227 seconds
# Block # 63  added to the blockchain
# Block ID: 63
# Previous Hash: 0000009dcc51e149046b2a7d18e3d1462102f4956e4b36e5ddbf7d9402bac89c
# Transactions: Transaction data 63
# Timestamp: 1714914594.8222375
# Nonce: 14136577
#
# ---------Adding block # 64 ---------
# Block mined successfully.
# Time taken: 93.00835394859314 seconds
# Block # 64  added to the blockchain
# Block ID: 64
# Previous Hash: 0000008d1e97a78178ca50a174f4e80b965df4eba33d7799996b220bd43a681a
# Transactions: Transaction data 64
# Timestamp: 1714914614.787657
# Nonce: 67451588
#
# ---------Adding block # 65 ---------
# Block mined successfully.
# Time taken: 33.53788447380066 seconds
# Block # 65  added to the blockchain
# Block ID: 65
# Previous Hash: 000000ba27b9eaaf838d9f86baede17298655c9f91fe6de9b507a5dbb4ae6c58
# Transactions: Transaction data 65
# Timestamp: 1714914707.7962105
# Nonce: 23802545
#
# ---------Adding block # 66 ---------
# Block mined successfully.
# Time taken: 2.797844409942627 seconds
# Block # 66  added to the blockchain
# Block ID: 66
# Previous Hash: 000000b1dbf3b6403984365beea7ad1d70b614b923679073eea409cdf7f2e988
# Transactions: Transaction data 66
# Timestamp: 1714914741.3343403
# Nonce: 2020657
#
# ---------Adding block # 67 ---------
# Block mined successfully.
# Time taken: 2.6396260261535645 seconds
# Block # 67  added to the blockchain
# Block ID: 67
# Previous Hash: 000000dc9519297a561e79be99302267f66602185c938825e0120f63e96ae750
# Transactions: Transaction data 67
# Timestamp: 1714914744.132353
# Nonce: 1879372
#
# ---------Adding block # 68 ---------
# Block mined successfully.
# Time taken: 25.592183589935303 seconds
# Block # 68  added to the blockchain
# Block ID: 68
# Previous Hash: 000000e697de3f01cb0a73dacb5ceb2af87d150953db25d05c5221e0b353cc29
# Transactions: Transaction data 68
# Timestamp: 1714914746.7721517
# Nonce: 17854256
#
# ---------Adding block # 69 ---------
# Block mined successfully.
# Time taken: 29.304996252059937 seconds
# Average time taken to mine a block: 30.208539724349976 seconds
# Difficulty adjusted to: 5
# Block # 69  added to the blockchain
# Block ID: 69
# Previous Hash: 000000eb53f88209c4422d07ea4003b5fb862db07e41476af15f9c76e8dfc474
# Transactions: Transaction data 69
# Timestamp: 1714914772.3645382
# Nonce: 20303585
#
# ---------Adding block # 70 ---------
# Block mined successfully.
# Time taken: 0.9095652103424072 seconds
# Block # 70  added to the blockchain
# Block ID: 70
# Previous Hash: 0000005d344500fce6180e8feff886b88f9dd81173407dc7cf3e7168806d9dbb
# Transactions: Transaction data 70
# Timestamp: 1714914801.6697435
# Nonce: 631897
#
# ---------Adding block # 71 ---------
# Block mined successfully.
# Time taken: 1.7554798126220703 seconds
# Block # 71  added to the blockchain
# Block ID: 71
# Previous Hash: 00000b60f27a50194362f429604ac490d3ecfdaba00f7bfac958f69bd16a87dc
# Transactions: Transaction data 71
# Timestamp: 1714914802.5794983
# Nonce: 1209016
#
# ---------Adding block # 72 ---------
# Block mined successfully.
# Time taken: 1.6597371101379395 seconds
# Block # 72  added to the blockchain
# Block ID: 72
# Previous Hash: 00000ac5fbb7639472307118a8bde405ccfdae25c367f268695c291d7e14f1ff
# Transactions: Transaction data 72
# Timestamp: 1714914804.3352368
# Nonce: 1161945
#
# ---------Adding block # 73 ---------
# Block mined successfully.
# Time taken: 2.6597399711608887 seconds
# Block # 73  added to the blockchain
# Block ID: 73
# Previous Hash: 00000c28d3d6539a58b2685fb87ae5591b85f6b351ca3a0c8e607ae3b62a95f2
# Transactions: Transaction data 73
# Timestamp: 1714914805.9952102
# Nonce: 1853711
#
# ---------Adding block # 74 ---------
# Block mined successfully.
# Time taken: 0.045647621154785156 seconds
# Block # 74  added to the blockchain
# Block ID: 74
# Previous Hash: 000002cdfad9e6b9c520532646d68873d8f20758e7dafba31fc31af9452e53c2
# Transactions: Transaction data 74
# Timestamp: 1714914808.6556988
# Nonce: 30726
#
# ---------Adding block # 75 ---------
# Block mined successfully.
# Time taken: 0.9504826068878174 seconds
# Block # 75  added to the blockchain
# Block ID: 75
# Previous Hash: 000005a2587ebde93578c34168b8a22cc67146535b54bd701a9cf58e73ff3eb2
# Transactions: Transaction data 75
# Timestamp: 1714914808.7014697
# Nonce: 656024
#
# ---------Adding block # 76 ---------
# Block mined successfully.
# Time taken: 3.9332754611968994 seconds
# Block # 76  added to the blockchain
# Block ID: 76
# Previous Hash: 000008cdfeab4e13eb5a609339ae06613033183405c8536ab098916bdb2808b2
# Transactions: Transaction data 76
# Timestamp: 1714914809.6521142
# Nonce: 2786942
#
# ---------Adding block # 77 ---------
# Block mined successfully.
# Time taken: 1.0772814750671387 seconds
# Block # 77  added to the blockchain
# Block ID: 77
# Previous Hash: 00000bd430114f3bed0eb01376025c2b20845c12ae50d861154aefa635fb25c4
# Transactions: Transaction data 77
# Timestamp: 1714914813.5856483
# Nonce: 767023
#
# ---------Adding block # 78 ---------
# Block mined successfully.
# Time taken: 0.19358611106872559 seconds
# Block # 78  added to the blockchain
# Block ID: 78
# Previous Hash: 00000588c67dd5a6c64af9bbd13258f3c0dd71200294d427a048d120b080c3d3
# Transactions: Transaction data 78
# Timestamp: 1714914814.6631002
# Nonce: 132974
#
# ---------Adding block # 79 ---------
# Block mined successfully.
# Time taken: 0.8061904907226562 seconds
# Average time taken to mine a block: 1.3990985870361328 seconds
# Difficulty adjusted to: 6
# Block # 79  added to the blockchain
# Block ID: 79
# Previous Hash: 00000d95d55a2949a3a94ed304086387f94d6e5a17a1b9fed5aaca5173de7ad3
# Transactions: Transaction data 79
# Timestamp: 1714914814.8567932
# Nonce: 553171
#
# ---------Adding block # 80 ---------
# Block mined successfully.
# Time taken: 7.415343523025513 seconds
# Block # 80  added to the blockchain
# Block ID: 80
# Previous Hash: 0000098591793649e4ed39c169bdb4a89a54d81fc9f481324df8f2773ad95917
# Transactions: Transaction data 80
# Timestamp: 1714914815.663196
# Nonce: 5339344
#
# ---------Adding block # 81 ---------
# Block mined successfully.
# Time taken: 21.04351806640625 seconds
# Block # 81  added to the blockchain
# Block ID: 81
# Previous Hash: 000000743cff8d8e1c475ac385a9104850ec600342d5ba8af79f22019ac8a5d3
# Transactions: Transaction data 81
# Timestamp: 1714914823.0787284
# Nonce: 14659304
#
# ---------Adding block # 82 ---------
# Block mined successfully.
# Time taken: 3.5935428142547607 seconds
# Block # 82  added to the blockchain
# Block ID: 82
# Previous Hash: 000000100490c4d059d9aebe7b11ecc213666ec6555842f2016a449d5d2b0a35
# Transactions: Transaction data 82
# Timestamp: 1714914844.1224403
# Nonce: 2528440
#
# ---------Adding block # 83 ---------
# Block mined successfully.
# Time taken: 19.0907621383667 seconds
# Block # 83  added to the blockchain
# Block ID: 83
# Previous Hash: 000000f20a7dfcb7f89589d489678fb379bdf0fa52eafe0ca68cc2cddba27b5f
# Transactions: Transaction data 83
# Timestamp: 1714914847.7162492
# Nonce: 13115260
#
# ---------Adding block # 84 ---------
# Block mined successfully.
# Time taken: 0.5277187824249268 seconds
# Block # 84  added to the blockchain
# Block ID: 84
# Previous Hash: 000000d924a6e862da413f77008056d3451ebfbcb971d11700c4d967956386a8
# Transactions: Transaction data 84
# Timestamp: 1714914866.807411
# Nonce: 387204
#
# ---------Adding block # 85 ---------
# Block mined successfully.
# Time taken: 9.97339415550232 seconds
# Block # 85  added to the blockchain
# Block ID: 85
# Previous Hash: 000000638ac04d0ab1d663a75545b1d02ddfb50d7219cf5d017dba399827a59c
# Transactions: Transaction data 85
# Timestamp: 1714914867.3354225
# Nonce: 6852528
#
# ---------Adding block # 86 ---------
# Block mined successfully.
# Time taken: 47.81863856315613 seconds
# Block # 86  added to the blockchain
# Block ID: 86
# Previous Hash: 00000038e6a90193682caab5031a2c3aa286e7c2cecdebe124bc2339f93c944e
# Transactions: Transaction data 86
# Timestamp: 1714914877.3090057
# Nonce: 32985140
#
# ---------Adding block # 87 ---------
# Block mined successfully.
# Time taken: 11.861008405685425 seconds
# Block # 87  added to the blockchain
# Block ID: 87
# Previous Hash: 0000003db2edbb154c22081a2f418500388d65560710ea8f6cd93183c0be10d0
# Transactions: Transaction data 87
# Timestamp: 1714914925.1278498
# Nonce: 8174458
#
# ---------Adding block # 88 ---------
# Block mined successfully.
# Time taken: 14.289990186691284 seconds
# Block # 88  added to the blockchain
# Block ID: 88
# Previous Hash: 000000d27d43a29355b20a1f54d30ede85806d3e3f5d9b39c7bcde58c3d4d98f
# Transactions: Transaction data 88
# Timestamp: 1714914936.9891334
# Nonce: 9823603
#
# ---------Adding block # 89 ---------
# Block mined successfully.
# Time taken: 63.05805325508118 seconds
# Average time taken to mine a block: 19.867196989059448 seconds
# Difficulty adjusted to: 6
# Block # 89  added to the blockchain
# Block ID: 89
# Previous Hash: 0000004f8bd1b2b1461c9fe5017d53b8612ff4c957a4627d47ac4d992fa20830
# Transactions: Transaction data 89
# Timestamp: 1714914951.2794096
# Nonce: 43721515
#
# ---------Adding block # 90 ---------
# Block mined successfully.
# Time taken: 7.131339073181152 seconds
# Block # 90  added to the blockchain
# Block ID: 90
# Previous Hash: 00000093e9a72537236098f6efefd022ec6d14251b115aa111764d61fa356743
# Transactions: Transaction data 90
# Timestamp: 1714915014.3376558
# Nonce: 4923640
#
# ---------Adding block # 91 ---------
# Block mined successfully.
# Time taken: 2.4460244178771973 seconds
# Block # 91  added to the blockchain
# Block ID: 91
# Previous Hash: 000000476823239c8d487f99bc921aa5ab8e227e570bff2ee5bca247ce298ed1
# Transactions: Transaction data 91
# Timestamp: 1714915021.4691763
# Nonce: 1665694
#
# ---------Adding block # 92 ---------
# Block mined successfully.
# Time taken: 19.102638483047485 seconds
# Block # 92  added to the blockchain
# Block ID: 92
# Previous Hash: 000000e26fd9099eb485977f4083e9f9737472907415b45001dfd922ceaee018
# Transactions: Transaction data 92
# Timestamp: 1714915023.9153826
# Nonce: 13169268
#
# ---------Adding block # 93 ---------
# Block mined successfully.
# Time taken: 64.84582448005676 seconds
# Block # 93  added to the blockchain
# Block ID: 93
# Previous Hash: 0000006c936939c1a6931de206277633423e37584136d8090d616dd5b76ec0ce
# Transactions: Transaction data 93
# Timestamp: 1714915043.0182078
# Nonce: 44827458
#
# ---------Adding block # 94 ---------
# Block mined successfully.
# Time taken: 11.131715536117554 seconds
# Block # 94  added to the blockchain
# Block ID: 94
# Previous Hash: 0000007058a5924bdfbd01f7f02d0c7fac13bf0e06755b78402df7cf76ac0121
# Transactions: Transaction data 94
# Timestamp: 1714915107.8642836
# Nonce: 7629320
#
# ---------Adding block # 95 ---------
# Block mined successfully.
# Time taken: 13.652509450912476 seconds
# Block # 95  added to the blockchain
# Block ID: 95
# Previous Hash: 0000007fb51306bbb46b0f4d878152f7776e61a4530301441e70f08b2a0e35d9
# Transactions: Transaction data 95
# Timestamp: 1714915118.9961762
# Nonce: 9581002
#
# ---------Adding block # 96 ---------
# Block mined successfully.
# Time taken: 6.221863031387329 seconds
# Block # 96  added to the blockchain
# Block ID: 96
# Previous Hash: 00000034257ccf145b3eb81df14e5864b240628cfd7a20f109645ec1d833de7d
# Transactions: Transaction data 96
# Timestamp: 1714915132.6488643
# Nonce: 4334972
#
# ---------Adding block # 97 ---------
# Block mined successfully.
# Time taken: 20.8236665725708 seconds
# Block # 97  added to the blockchain
# Block ID: 97
# Previous Hash: 000000cc7c05f9b06508ad09657aa5065d566e0983421785e54c7a7ea47f0b52
# Transactions: Transaction data 97
# Timestamp: 1714915138.8709006
# Nonce: 14536842
#
# ---------Adding block # 98 ---------
# Block mined successfully.
# Time taken: 4.5979979038238525 seconds
# Block # 98  added to the blockchain
# Block ID: 98
# Previous Hash: 000000a9f0f0c4e65e68eb64977d031fc201e1edb6e9be4f2a343e148ee039e8
# Transactions: Transaction data 98
# Timestamp: 1714915159.6947527
# Nonce: 3243659
#
# ---------Adding block # 99 ---------
# Block mined successfully.
# Time taken: 29.570490837097168 seconds
# Average time taken to mine a block: 17.95240697860718 seconds
# Difficulty adjusted to: 6
# Block # 99  added to the blockchain
# Block ID: 99
# Previous Hash: 0000002466cea90eec94c4e70fe4534348476e9c6b7ebc25820ea725f1f19eb3
# Transactions: Transaction data 99
# Timestamp: 1714915164.2929265
# Nonce: 20450926

# %% [markdown]
# ## Merkle Tree

# %% [markdown]
# ### Overview
# The Merkle Tree is a data structure used to efficiently organize and verify the integrity of transactions within a block in a blockchain.

# %% [markdown]
# The Merkle Tree significantly reduces the data needed for proving the validity of a transaction in a blockchain.
#
# In a blockchain, each block contains a large number of transactions. Without a Merkle Tree, verifying the inclusion of a transaction would require providing all the transactions in the block, which could be computationally expensive and inefficient, especially for large blocks.
#
# However, with a Merkle Tree, the proof of inclusion for a transaction requires providing only a subset of hashes from the tree, known as the Merkle path. This path consists of hashes of sibling nodes along the path from the transaction's leaf node to the root of the tree.
#
# The length of the Merkle path is logarithmic in the number of transactions in the block. Specifically, if a block contains 𝑛 transactions, the length of the Merkle path is approximately log₂(𝑛).
#
# For example, if a block contains 1,000 transactions, the Merkle path would require providing only about 10 hashes (assuming a balanced Merkle Tree). This is a significant reduction compared to providing all 1,000 transactions.
#
# Therefore, the Merkle Tree greatly reduces the amount of data needed for proving the validity of a transaction, making blockchain verification more efficient and scalable.

# %% [markdown]
# ### Implementation
# Next, we'll implement the Merkle Tree data structure, including functions for building the tree, retrieving Merkle proofs, and validating proofs.

# %%
class MerkleNode:
    def __init__(self, data):
        self.data = data
        self.hash = hashlib.sha256(data.encode()).hexdigest()
        self.left = None
        self.right = None

class MerkleTree:
    def __init__(self, transactions):
        self.root = self.build_tree(transactions)

    def build_tree(self, transactions):
        if len(transactions) == 0:
            return None
        elif len(transactions) == 1:
            return MerkleNode(transactions[0])

        mid = len(transactions) // 2
        left_subtree = self.build_tree(transactions[:mid])
        right_subtree = self.build_tree(transactions[mid:])
        
        root = MerkleNode(left_subtree.hash + right_subtree.hash)
        root.left = left_subtree
        root.right = right_subtree

        return root

    def get_root(self):
        return self.root.hash if self.root else None

    def pretty_print(self, node, prefix="", is_left=True):
        if node is not None:
            self.pretty_print(node.right, prefix + ("│   " if is_left else "    "), False)
            print(prefix + ("└── " if is_left else "┌── ") + node.hash)
            self.pretty_print(node.left, prefix + ("    " if is_left else "│   "), True)

    def get_proof(self, transaction):
        if self.root is None:
            return None, []

        return self._get_proof_helper(self.root, transaction)

    def _get_proof_helper(self, node, transaction):
        if node is None:
            return None, []

        if node.data == transaction:
            return node.hash, []

        left_hash, left_proof = self._get_proof_helper(node.left, transaction)
        if left_hash is not None:
            left_proof.append(node.right.hash)
            return left_hash, left_proof

        right_hash, right_proof = self._get_proof_helper(node.right, transaction)
        if right_hash is not None:
            right_proof.append(node.left.hash)
            return right_hash, right_proof

        return None, []

# %%
def validate_proof(merkle_root_hash, transaction_hash, merkle_path):
    if not merkle_path:
        return transaction_hash == merkle_root_hash

    sibling_hash = merkle_path[0]
    computed_hash_1 = hashlib.sha256((transaction_hash + sibling_hash).encode()).hexdigest()
    computed_hash_2 = hashlib.sha256((sibling_hash + transaction_hash).encode()).hexdigest()

    left_path = validate_proof(merkle_root_hash, computed_hash_2, merkle_path[1:])
    right_path = validate_proof(merkle_root_hash, computed_hash_1, merkle_path[1:])

    return left_path or right_path

# %% [markdown]
# ### Usage Example
# We'll demonstrate the usage of the Merkle Tree by constructing a tree from a list of transactions, retrieving a Merkle proof for a transaction, and validating the proof.

# %%
transactions = [f"transaction{i}" for i in range(1, 20)]

merkle_tree = MerkleTree(transactions)

print("Merkle Root:", merkle_tree.get_root())
print("\nMerkle Tree:")
merkle_tree.pretty_print(merkle_tree.root)

transaction_to_verify = f'transaction{random.randint(1, 20)}'
print("\nVerifying transaction:", transaction_to_verify)
transaction_hash, merkle_path = merkle_tree.get_proof(transaction_to_verify)
print("\nTransaction Hash:", transaction_hash)
print("Merkle Path Length:", len(merkle_path), "\n","Merkle Path:", merkle_path)

is_valid = validate_proof(merkle_tree.get_root(), transaction_hash, merkle_path)
print("Is Valid:", is_valid)
# Out:
# Merkle Root: 1fee6174e1c18c1121343971627630a08ee0f6686c9707b1da6693fa7139ae50
#
# Merkle Tree:
# │                   ┌── 3fd376716c37283599026d83ee37735b98d74b31160ae9fdf471a3a77bee4cc2
# │               ┌── 0e44cbee5eb0f9cb478baa8c5a833a039644f6b03737e9b508077ae3358aca16
# │               │   └── 6e08d35bf9f37cd3b7248edce4b7093c0cd272ed311d6a3c3765259a4e231510
# │           ┌── 4044cd701a75c8d896cd9cdcfa542a4568e488f1fb55d56301337b0f1992ecfc
# │           │   └── 188201b43d49a2fe9031415f2053c70da18049a58555fce4c805b8873752a613
# │       ┌── 13cb5054b531e984104f288c2932246c4126722bf424bb74f9260b509ac45b55
# │       │   │   ┌── e0fd183f2da7e7e023020b293e1a29dbb503852e44b10f1908b1f04f7b86a7b0
# │       │   └── f8cfc1e06b95bde47b51de1ad7482a7117a81071946f35c59dd325fa91bf3172
# │       │       └── 13dc09b01344bb4c76726ab74cac547cc06a66c509d1731e14ff464563d52af6
# │   ┌── 76e94f3377e1201f7b024fc014e31d6af7dd8d1a2f58484459f7f708e934e1f5
# │   │   │           ┌── 2a75167b999815b6a4191cb78c9049c19ca82ceb3980dc794f35ed64d0e95dbc
# │   │   │       ┌── 9257407986f4e440e95407c7f8ef76565f7d6372aa600316bd23ae0480708edc
# │   │   │       │   └── bcf9ad825f013ce61c9bacf5f4c393c50c90571810e7804fcde81b0e25c53340
# │   │   │   ┌── 836d713af0c1e57fa6dbe9642db692fb7de5989cb470472d37c5a2835ea9283d
# │   │   │   │   └── f60cfcb38e8703c186d5697d06620632ea14abfbc03f92b2ff99e2d37ae6e2c9
# │   │   └── 93aab3c46bd143228252b0c98893158e873810332d445cab229ef5b782b734a5
# │   │       │   ┌── 244cbb4c15aba1b98e8d754c5b47d85944187c5c29e5d57d4af42025c8d05167
# │   │       └── 481c52b17bd79ccb95443f137ff299960a4718c1d8d2a281e4b458b69a7ce81a
# │   │           └── 0fbe4ca079c883dd26d53295ee2d091ed9a8551958f003508d1a13851d418fec
# └── 1fee6174e1c18c1121343971627630a08ee0f6686c9707b1da6693fa7139ae50
#     │               ┌── 0620fac861009d4d5b44b18c95ee63eefefbb5a0178276f6850c9c65da7455ab
#     │           ┌── d1d4c2e9dfeb90655e294c3c57cc6c24546e9e19993966c5501e2d11fdc32c78
#     │           │   └── 4f029880ea69372ae4d659e002cce9b6e87dfc608400d6e93f27a3862214980e
#     │       ┌── 858c037fc3daa9cf7ecbf7fb30665934ebe6cd5a895fabc5a65cc0b3c80aa73a
#     │       │   └── 221fb44023518da3908a8cefe5b97d1a42218e5a8316e35a7c4077302f8ed9a2
#     │   ┌── 781d5db43f7ab4fa437177be60fc0f99558e226d6b1258bf2939bc78c58198d1
#     │   │   │   ┌── 1fd4bbf0a645748595e05cc79a980bf10d65a17c50f63226e7f39993bc09a9f8
#     │   │   └── 1c41ec57607b6f4ae062e8b082e3739d15c81551f90603d1628deb5a8ffc590a
#     │   │       └── 26af218ec2912ce97d8dac14ce69b73e54d935139ad0186cf2cc99f927acfd96
#     └── f7952c0b63e38bf86ee119c3692b8766fe17b6005fcb20fe48cc441746f2c780
#         │       ┌── 2435dc0372e12b3f7684fb7093fbe6f6dee79dbff96cc28b1687839ef526e02f
#         │   ┌── 882ed7f97314e753d0084ea24c386afd3cbd0fb34b3744bfb81d9d3a925cc6e6
#         │   │   └── 293755ab6384e02d9202d483f2f0250100d786e75fdab1b6f3925b2800ece3cb
#         └── 0cf77e26eb4a27047852cf39e3868c7a69ff1109acb9e799ba422d3ac350fb97
#             │   ┌── 4beace8bdcf9b5b74630eaee2e7f501180e46025ca89b05e7e041fbe953d817a
#             └── 830b7f324af3ff2b2a47cf7cf5ac825fe8d8034294ea8e8f853a4d3fada893fc
#                 └── bde4693e55a336ff81ab238ce20cae1dd9c8ba03b9b8f43963f5569bf3cf5229
#
# Verifying transaction: transaction13
#
# Transaction Hash: bcf9ad825f013ce61c9bacf5f4c393c50c90571810e7804fcde81b0e25c53340
# Merkle Path Length: 5
#  Merkle Path: ['2a75167b999815b6a4191cb78c9049c19ca82ceb3980dc794f35ed64d0e95dbc', 'f60cfcb38e8703c186d5697d06620632ea14abfbc03f92b2ff99e2d37ae6e2c9', '481c52b17bd79ccb95443f137ff299960a4718c1d8d2a281e4b458b69a7ce81a', '13cb5054b531e984104f288c2932246c4126722bf424bb74f9260b509ac45b55', 'f7952c0b63e38bf86ee119c3692b8766fe17b6005fcb20fe48cc441746f2c780']
# Is Valid: True

# %% [markdown]
# Here we have a Merkle Tree with 1 000 000 transactions. We will show how to build the tree and how to retrieve the Merkle proof for a specific transaction, and verify the proof with the minimal amount of data needed.
#
# We can see that the Merkle proof for a transaction requires only 20 hashes, which is significantly less than providing all 1 000 000 transactions in the block.

# %%
transactions = [f"transaction{i}" for i in range(1, 1000000)]

merkle_tree = MerkleTree(transactions)

print("Merkle Root:", merkle_tree.get_root())

transaction_to_verify = f'transaction{random.randint(1, 1000000)}'
print("\nVerifying transaction:", transaction_to_verify)
transaction_hash, merkle_path = merkle_tree.get_proof(transaction_to_verify)
print("\nTransaction Hash:", transaction_hash)
print("Merkle Path Length:", len(merkle_path), "\n","Merkle Path:", merkle_path)

is_valid = validate_proof(merkle_tree.get_root(), transaction_hash, merkle_path)
print("Is Valid:", is_valid)
# Out:
# Merkle Root: 61a5161747dd55e52e64756ab03df21d44b6d199887099c76c1144279316a1bb
#
# Verifying transaction: transaction930318
#
# Transaction Hash: 566a09d9837fbf9f1a79493b3c70581a3072ebcd1a4a36388c67fb952c1fffcd
# Merkle Path Length: 20
#  Merkle Path: ['12a215a9ea6391ade49593db3eca46c04280f3280079d3fe60736e8a295d9aca', '2aff3974d11ba74812b72adfa4b08b8000a395a98c400bd906b085a51c38af51', '74d5320b7469463f1fd7838e5892590b485e8e94d0b143541831fe26d1296ef1', 'dcdf94ee1cc9c2957f1012e1beacaac81586b14264b605aede26cf81ec31f8b4', '2b3eec1d6e04eb686e2da03cba78dd4c0b6d5758bb11984f68ee67a18298530d', 'f46887479a90e319b56e0e1d55972547d79d57680cb98c48535a2163353df972', '83979dcf949cb69360a6d9587c2741e0c9ae1cbf58988f82283384685933bd86', '747b2174ede97770993cdb3101d164a9a4b81969d2572c19aee2f954f0c9a258', '7264836f41f62ead86ff4500afa73901455f0c4d19b39bab4cba0171ad7150de', '866d676a6b351de3454d91fa3c4b4c6040cc2980ba1ec43ef9e8dfbff642ef43', 'b73d75457ed18e106e87c814de90cb92a976c0cacf7b19397e593e7e9cf4231c', 'f3501aa7d522bad04333cd27c04f7c6f53bdd6d9ec0ddb97692b40ee4082816e', '84b02f67cd98641389e6599c83a23b497869ed0bf4df6673f74a81e48df394a0', 'f1b2741e6e5b35957b98f62a204f02bebb1491f5ab56df08da347ee892e4b7ae', '3c934612507cf7b13b1578af9b55c48f916d33a597a5f77bade38b6c69daca5e', 'dae7dfc131cd60a99147605cbb255852a6284be9bf08cb1c249f71b63a981ac0', '6b0a89f14242408b1c4c564a8b7ce4df1874440a49803d40086b443fbed1f418', 'd6f680739e051d129b059da92ccb182ad36d1bb62b71a70dc664bf84d17118a6', '404b133a3f2caf1113b2762a8f53b697b5ec8a4367a83b7330e132b70883e864', '89fb6673d1c500e3f21fa1277ebcb6df70c90f867a8a073b4838419555c9edf2']
# Is Valid: True

# %% [markdown]
# In this notebook, we created two important parts of blockchain technology: Proof of Work (PoW) and Merkle Trees.
#
# Proof of Work (PoW) is like a puzzle that miners solve to add blocks to the blockchain. It's hard to search for a solution but easy to check. This makes it tough for someone to cheat and proves the validity of the chain.
#
# Merkle Trees help keep transactions in blocks safe. They organize data efficiently, so it's easy to check if a transaction is valid.

# %% [markdown]
# Proof of Work (PoW):
# - Checking the validity of a hash: O(1), because it's a simple comparison.
#
#
# Merkle Trees:
# - Constructing a Merkle Tree from a list of transactions: O(n), where n is the number of transactions.
# - Verifying a transaction in a Merkle Tree: O(log n), where n is the number of transactions, because you need to traverse the tree from the leaf to the root.

# %% [markdown]
# # References
# Nakamoto, S. (2008) "Bitcoin: A Peer-to-Peer Electronic Cash System." https://bitcoin.org/bitcoin.pdf
#
# Liu, H., Luo, X., Liu, H. and Xia, X. (2021) "Merkle Tree: A Fundamental Component of Blockchains", International Conference on Electronic Information Engineering and Computer Science (EIECS), pp. 556-561, doi: 10.1109/EIECS53707.2021.9588047. https://ieeexplore.ieee.org/document/9588047
